# %%
import matplotlib.pyplot as plt
dic = ast.literal_eval(open("report/evaluation.txt",'r+').read())
a = [dic['Good RMSE'],dic['RMSE'],dic['Bad RMSE']]
fig, ax = plt.subplots()
plt.bar(range(len(a)),a,label="RMSE score")
ax.set_xlabel('RMSE')
ax.set_ylabel('Scores')
ax.set_xticks(range(len(a)))
ax.set_xticklabels(['Good', 'Average', 'Bad'])
plt.show()

# %%
b = [dic['Good MAE'],dic['MAE'],dic['Bad MAE']]
fig, ax = plt.subplots()
plt.bar(range(len(b)),b,label="MAE score")
ax.set_xlabel('MAE')
ax.set_ylabel('Scores')
ax.set_xticks(range(len(b)))
ax.set_xticklabels(['Good', 'Average', 'Bad'])
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import datetime

x = [datetime.datetime(2011, 1, 4, 0, 0),
     datetime.datetime(2011, 1, 5, 0, 0),
     datetime.datetime(2011, 1, 6, 0, 0)]
x = date2num(x)
print(x)
y = a
z=b

ax = plt.subplot(111)
ax.bar(x-0.2, y,width=0.2,color='r',align='center')
ax.bar(x, z,width=0.2,color='y',align='center')
ax.xaxis_date()
ax.set_xticklabels( ('Good', 'Average', 'Bad') )

plt.show()

# %%
# Performance of Recommendation Model
import numpy as np
import matplotlib.pyplot as plt

N = 3
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = a
rects1 = ax.bar(ind, yvals, width, color='k')
zvals = b
rects2 = ax.bar(ind+width, zvals, width, color='y')

ax.set_ylabel('Scores')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Good', 'Average', 'Bad') )
ax.legend( (rects1[0], rects2[0]), ('RMSE', 'MAE') )

def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 0.99*h, '%.2f'%float(h),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
import ast
x = ast.literal_eval(open("report/rmse.txt",'r+').read())
y = ast.literal_eval(open("report/mae.txt",'r+').read())
plt.plot(range(len(x)),x)
plt.plot(range(len(y)),y)
plt.xlabel("Iteration")
plt.ylabel("Scores")
plt.legend(['RMSE', 'MAE'], loc='upper left')
plt.savefig('metric_com.png')
plt.show()

# %%
import ast
import pandas as pd
dic = ast.literal_eval(open("report/re_edit/pop_people_metrices.txt",'r+').read())
recall_at_10 = []
recall_at_5 = []
for i in dic:
    recall_at_10.append(i['recall@10'])
    recall_at_5.append(i['recall@5'])
    
print(sum(recall_at_10)/len(recall_at_10))
print(sum(recall_at_5)/len(recall_at_5))
# Out:
# 0.427548959347487
# 0.36691963041132314

# %%
recall5 = [min(recall_at_5),sum(recall_at_5)/len(recall_at_5),max(recall_at_5)]
recall10 = [min(recall_at_10),sum(recall_at_10)/len(recall_at_10),max(recall_at_10)]

# %%
# Performance of Recommendation Model
import numpy as np
import matplotlib.pyplot as plt

N = 3
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = recall5
rects1 = ax.bar(ind, yvals, width, color='r')
zvals = recall10
rects2 = ax.bar(ind+width, zvals, width, color='g')

ax.set_ylabel('Scores')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Bad', 'Average', 'Good') )
ax.legend( (rects1[0], rects2[0]), ('recall5', 'recall10') )

def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 0.99*h, '%.2f'%float(h),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()

# %%
import ast
import pandas as pd
dic = ast.literal_eval(open("report/pop_re/pop_people_metrices.txt",'r+').read())
recall_at_10 = []
recall_at_5 = []
for i in dic:
    recall_at_10.append(i['recall@10'])
    recall_at_5.append(i['recall@5'])
    
recall5 = [min(recall_at_5),sum(recall_at_5)/len(recall_at_5),max(recall_at_5)]
recall10 = [min(recall_at_10),sum(recall_at_10)/len(recall_at_10),max(recall_at_10)]

# %%
# Performance of Recommendation Model
import numpy as np
import matplotlib.pyplot as plt

N = 3
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = recall5
rects1 = ax.bar(ind, yvals, width, color='r')
zvals = recall10
rects2 = ax.bar(ind+width, zvals, width, color='g')

ax.set_ylabel('Scores')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Bad', 'Average', 'Good') )
ax.legend( (rects1[0], rects2[0]), ('recall5', 'recall10') )

def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 0.99*h, '%.2f'%float(h),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

#plt.show()

# %%
import ast
import pandas as pd
dic = ast.literal_eval(open("report/popular/pop_people_metrices.txt",'r+').read())
recall_at_10 = []
recall_at_5 = []
for i in dic:
    recall_at_10.append(i['recall@10'])
    recall_at_5.append(i['recall@5'])
    
recall5 = [min(recall_at_5),sum(recall_at_5)/len(recall_at_5),max(recall_at_5)]
recall10 = [min(recall_at_10),sum(recall_at_10)/len(recall_at_10),max(recall_at_10)]

# Performance of Recommendation Model
import numpy as np
import matplotlib.pyplot as plt

N = 3
ind = np.arange(N)  # the x locations for the groups
width = 0.27       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

yvals = recall5
rects1 = ax.bar(ind, yvals, width, color='r')
zvals = recall10
rects2 = ax.bar(ind+width, zvals, width, color='g')

ax.set_ylabel('Scores')
ax.set_xticks(ind+width)
ax.set_xticklabels( ('Bad', 'Average', 'Good') )
ax.legend( (rects1[0], rects2[0]), ('recall5', 'recall10') )

def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 0.99*h, '%.2f'%float(h),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()
